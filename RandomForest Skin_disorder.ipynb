# %% [markdown]
# ## 1. Importing the necessary packages

# %%
# Importing the necessary function
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
#Importing & defining the datframe
df=pd.read_csv('dataset_35_dermatology.csv')
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %% [markdown]
# ## 2. Basic checks

# %%
df.shape
# Out:
# (366, 35)

# %%
df.size
# Out:
# 12810

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   erythema                                  366 non-null    int64
#  1   scaling                                   366 non-null    int64
#  2   definite_borders                          366 non-null    int64
#  3   itching                                   366 non-null    int64
#  4   koebner_phenomenon                        366 non-null    int64
#  5   polygonal_papules                         366 non-null    int64
#  6   follicular_papules                        366 non-null    int64
#  7   oral_mucosal_involvement                  366 non-null    int64
#  8   knee_and_elbow_involvement                366 non-null    int64
#  9   scalp_involvement                         366 non-null    int64
# ...

# %% [markdown]
# ## 3. Checking the null Values

# %%
df.replace('?',np.nan,inplace=True)
df.head(5)
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
df.isnull().sum()
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# PNL_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %% [markdown]
# ## 4 Replacing The nulll values with mean

# %%
columns = ['Age']
for col in columns:
    df[col]=pd.to_numeric(df[col])
    df[col].fillna(df[col].mean(), inplace=True)
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
df.isnull().sum()
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# PNL_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %%
df.shape # Shape of a DataFrame
# Out:
# (366, 35)

# %% [markdown]
# ## 5. Defining the 'X' and 'y'

# %%
X=df.iloc[:,:34]
X.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  focal_hypergranulosis  \
# ...

# %%
y=df['class']
y.head()
# Out:
# 0    2
# 1    1
# 2    3
# 3    1
# 4    3
# Name: class, dtype: int64

# %% [markdown]
# ## 6. Model-3 => RandomForest Model

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=25)

# %%
from sklearn.ensemble import RandomForestClassifier #Defining the model
model=RandomForestClassifier(n_estimators=100,max_depth=15,random_state=4)#n_estimators=100,max_depth=15,random_state=4

# %%
model.fit(X_train,y_train) ## fitting the data
# Out:
# RandomForestClassifier(max_depth=15, random_state=4)

# %%
y_predict=model.predict(X_test)

# %% [markdown]
# ## 7. Model Evaluation

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.9864864864864865

# %%
print(classification_report(y_test,y_predict)) # Classification Report
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        21
#            2       1.00      0.94      0.97        18
#            3       1.00      1.00      1.00        15
#            4       0.89      1.00      0.94         8
#            5       1.00      1.00      1.00         9
#            6       1.00      1.00      1.00         3
#
#     accuracy                           0.99        74
#    macro avg       0.98      0.99      0.99        74
# weighted avg       0.99      0.99      0.99        74

# %%
confusion_matrix(y_test,y_predict) # Confusion matrix
# Out:
# array([[21,  0,  0,  0,  0,  0],
#        [ 0, 17,  0,  1,  0,  0],
#        [ 0,  0, 15,  0,  0,  0],
#        [ 0,  0,  0,  8,  0,  0],
#        [ 0,  0,  0,  0,  9,  0],
#        [ 0,  0,  0,  0,  0,  3]], dtype=int64)

# %% [markdown]
# ## 8.Model Evaluation with Cross validation

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model,X,y,cv=10,scoring="accuracy")
print(scores)
# Out:
# [0.94594595 1.         1.         1.         1.         0.94594595
#  1.         0.97222222 0.97222222 0.97222222]

# %%
print("Average Accuracy:",scores.mean())
print("Std:",scores.std())
#std of < 0.05 is good.
# Out:
# Average Accuracy: 0.9808558558558558
# Std: 0.021197909765008262

# %% [markdown]
# ### 8.1 Using GridSearchCV & RandomizedSearchCV

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV 
parameters = {'max_depth':[15,16,18,19,20],
              'random_state': [1,2,3,4,5],
              'n_estimators':[80,90,100,110,120] 
             }  # dictionary of parameters.  5x5x5 = 125.
grid = GridSearchCV(model,parameters,cv=5,verbose=1)
#grid = RandomizedSearchCV(model,parameters,cv=5)
grid.fit(X,y)
# Out:
# Fitting 5 folds for each of 125 candidates, totalling 625 fits
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(max_depth=15, random_state=4),
#              param_grid={'max_depth': [15, 16, 18, 19, 20],
#                          'n_estimators': [80, 90, 100, 110, 120],
#                          'random_state': [1, 2, 3, 4, 5]},
#              verbose=1)

# %%
print(grid.best_score_) #Best score
print(grid.best_params_) #for best parameters
# Out:
# 0.9781562384302112
# {'max_depth': 15, 'n_estimators': 80, 'random_state': 4}

# %% [markdown]
# ## The Avarage accuracy Score of K-Nearest Neighbors model with Cross_val is = 0.980855

# %% [markdown]
# Please prefer other notebook for different model
